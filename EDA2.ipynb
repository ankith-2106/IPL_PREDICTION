# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('D:\DBDA\Final_Project\project_01\part_02\Dataset')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_10120\2440764686.py:1: SyntaxWarning: invalid escape sequence '\D'
#   os.chdir('D:\DBDA\Final_Project\project_01\part_02\Dataset')

# %%
deliveries = pd.read_csv('cleaned_deliveries.csv')

# %%
matches = pd.read_csv('matches.csv')

# %%
pd.pandas.set_option('display.max_column',None)

# %%
pd.pandas.set_option('display.max_row',None)

# %%
deliveries.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    260920 non-null  object
# ...

# %%
deliveries.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind           0
# fielder             251566
# dtype: int64

# %%
deliveries[deliveries['extras_type'].isnull()].head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 5    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 7    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     1
#
#    ball       batter   bowler non_striker  batsman_runs  extra_runs  \
# 1     2  BB McCullum  P Kumar  SC Ganguly             0           0
# 3     4  BB McCullum  P Kumar  SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar  SC Ganguly             0           0
# 5     6  BB McCullum  P Kumar  SC Ganguly             0           0
# 7     1  BB McCullum   Z Khan  SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
deliveries['extras_type'].fillna('None',inplace = True)
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_10120\3472493188.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   deliveries['extras_type'].fillna('None',inplace = True)

# %%
deliveries['player_dismissed'].fillna('None',inplace=True)
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_10120\818535281.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   deliveries['player_dismissed'].fillna('None',inplace=True)

# %%
deliveries['fielder'].fillna('None',inplace=True)
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_10120\801782388.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   deliveries['fielder'].fillna('None',inplace=True)

# %%
deliveries.isnull().sum()
# Out:
# match_id            0
# inning              0
# batting_team        0
# bowling_team        0
# over                0
# ball                0
# batter              0
# bowler              0
# non_striker         0
# batsman_runs        0
# extra_runs          0
# total_runs          0
# extras_type         0
# is_wicket           0
# player_dismissed    0
# dismissal_kind      0
# fielder             0
# dtype: int64

# %%
deliveries.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
matches.head()
# Out:
#        id   season        city       date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  4/18/2008     League     BB McCullum
# 1  335983  2007/08  Chandigarh  4/19/2008     League      MEK Hussey
# 2  335984  2007/08       Delhi  4/19/2008     League     MF Maharoof
# 3  335985  2007/08      Mumbai  4/20/2008     League      MV Boucher
# 4  335986  2007/08     Kolkata  4/20/2008     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
matches.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
matches[matches['city'].isnull()].head()
# Out:
#          id season city       date match_type player_of_match  \
# 399  729281   2014  NaN  4/17/2014     League       YS Chahal
# 402  729287   2014  NaN  4/19/2014     League        PA Patel
# 403  729289   2014  NaN  4/19/2014     League       JP Duminy
# 404  729291   2014  NaN  4/20/2014     League      GJ Maxwell
# 406  729295   2014  NaN  4/22/2014     League      GJ Maxwell
#
#                                    venue                        team1  \
# 399              Sharjah Cricket Stadium             Delhi Daredevils
# 402  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 403  Dubai International Cricket Stadium        Kolkata Knight Riders
# 404              Sharjah Cricket Stadium             Rajasthan Royals
# 406              Sharjah Cricket Stadium              Kings XI Punjab
#
#                            team2                  toss_winner toss_decision  \
# 399  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
matches['city'].fillna('Dubai',inplace=True)
# Out:
# C:\Users\PC-ASUS\AppData\Local\Temp\ipykernel_10120\1577451452.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   matches['city'].fillna('Dubai',inplace=True)

# %%
matches.isnull().sum()
# Out:
# id                    0
# season                0
# city                  0
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
matches[matches['result_margin'].isnull()].head()
# Out:
#          id   season       city       date match_type player_of_match  \
# 66   392190     2009  Cape Town  4/23/2009     League       YK Pathan
# 130  419121  2009/10    Chennai  3/21/2010     League        J Theron
# 241  501265     2011      Delhi  5/21/2011     League             NaN
# 328  598004     2013  Hyderabad   4/7/2013     League       GH Vihari
# 342  598017     2013  Bangalore  4/16/2013     League         V Kohli
#
#                                          venue                        team1  \
# 66                                    Newlands        Kolkata Knight Riders
# 130            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 241                           Feroz Shah Kotla             Delhi Daredevils
# 328  Rajiv Gandhi International Stadium, Uppal          Sunrisers Hyderabad
# 342                      M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
matches.result.unique()
# Out:
# array(['runs', 'wickets', 'tie', 'no result'], dtype=object)

# %%
matches = matches.iloc[np.where(matches['result']!='tie')]

# %%
matches = matches.iloc[np.where(matches['result']!='no result')]

# %%
matches.result.unique()
# Out:
# array(['runs', 'wickets'], dtype=object)

# %%
matches.isnull().sum()
# Out:
# id                    0
# season                0
# city                  0
# date                  0
# match_type            0
# player_of_match       0
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                0
# result                0
# result_margin         0
# target_runs           0
# target_overs          0
# super_over            0
# method             1055
# umpire1               0
# umpire2               0
# dtype: int64

# %%
matches[matches.method.isnull()].head()
# Out:
#        id   season        city       date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  4/18/2008     League     BB McCullum
# 1  335983  2007/08  Chandigarh  4/19/2008     League      MEK Hussey
# 2  335984  2007/08       Delhi  4/19/2008     League     MF Maharoof
# 3  335985  2007/08      Mumbai  4/20/2008     League      MV Boucher
# 4  335986  2007/08     Kolkata  4/20/2008     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
matches=matches.drop(['method','super_over'],axis=1)

# %%
matches.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# match_type         0
# player_of_match    0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# target_runs        0
# target_overs       0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
matches = matches.drop(['season','date','match_type'],axis=1)

# %%
matches.head(20)
# Out:
#         id        city player_of_match  \
# 0   335982   Bangalore     BB McCullum
# 1   335983  Chandigarh      MEK Hussey
# 2   335984       Delhi     MF Maharoof
# 3   335985      Mumbai      MV Boucher
# 4   335986     Kolkata       DJ Hussey
# 5   335987      Jaipur       SR Watson
# 6   335988   Hyderabad        V Sehwag
# 7   335989     Chennai       ML Hayden
# 8   335990   Hyderabad       YK Pathan
# 9   335991  Chandigarh   KC Sangakkara
# 10  335992   Bangalore       SR Watson
# 11  335993     Chennai        JDP Oram
# 12  335994      Mumbai    AC Gilchrist
# 13  335995  Chandigarh       SM Katich
# 14  335996   Bangalore        MS Dhoni
# 15  335997     Kolkata   ST Jayasuriya
# 16  335998       Delhi      GD McGrath
# 17  335999   Hyderabad        SE Marsh
# 18  336000      Jaipur     SA Asnodkar
# 19  336001     Chennai        V Sehwag
#
#                                          venue                        team1  \
# ...

# %%
deliveries.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
team_name_changes = {
    'Royal Challengers Bangalore': 'Royal Challengers Bengaluru',
    'Kings XI Punjab': 'Punjab Kings',
    'Delhi Daredevils': 'Delhi Capitals',
    'Deccan Chargers': 'Sunrisers Hyderabad',
    'Pune Warriors': 'Rising Pune Supergiants',
    'Rising Pune Supergiant': 'Rising Pune Supergiants',
    'Gujarat Lions': 'Gujarat Titans'
}
matches.replace(team_name_changes, inplace=True)

# %%
matches.head()
# Out:
#        id        city player_of_match  \
# 0  335982   Bangalore     BB McCullum
# 1  335983  Chandigarh      MEK Hussey
# 2  335984       Delhi     MF Maharoof
# 3  335985      Mumbai      MV Boucher
# 4  335986     Kolkata       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 1  Punjab Cricket Association Stadium, Mohali                 Punjab Kings
# 2                            Feroz Shah Kotla               Delhi Capitals
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bengaluru         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# ...

# %%
# deliveries.merge()

# %%
deliveries.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
merged_df = pd.merge(deliveries, matches, left_on='match_id', right_on='id', how='left')

# %%
merged_df.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# ...

# %%
merged_df = merged_df.drop(['id','team1','team2'],axis=1)

# %%
merged_df.head(50)
# Out:
#     match_id  inning           batting_team                 bowling_team  \
# 0     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 5     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 6     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 7     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 8     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 9     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 10    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 11    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...

# %%
merged_df.extras_type.unique()
# Out:
# array(['legbyes', 'None', 'wides', 'byes', 'noballs', 'penalty'],
#       dtype=object)

# %%
merged_df.batsman_runs.unique()
# Out:
# array([0, 4, 6, 1, 2, 5, 3], dtype=int64)

# %%
merged_df[merged_df['extras_type']=='penalty'].head(10)
# Out:
#        match_id  inning      batting_team     bowling_team  over  ball  \
# 1614     335988       2  Delhi Daredevils  Deccan Chargers    11     6
# 98231    729309       2  Delhi Daredevils   Mumbai Indians     4     2
#
#          batter      bowler non_striker  batsman_runs  extra_runs  total_runs  \
# 1614   V Sehwag     PP Ojha    S Dhawan             0           5           5
# 98231   M Vijay  SL Malinga   Q de Kock             0           7           7
#
#       extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# 1614      penalty          0             None        Not-out    None
# 98231     penalty          0             None        Not-out    None
#
#             city player_of_match                                      venue  \
# 1614   Hyderabad        V Sehwag  Rajiv Gandhi International Stadium, Uppal
# 98231      Dubai         M Vijay                    Sharjah Cricket Stadium
#
#                toss_winner toss_decision          winner   result  \
# ...

# %%
merged_df.shape
# Out:
# (260920, 29)

# %%
imp=[]
for i in merged_df['extras_type'].unique():
    imp.append(i)

print(imp)
# Out:
# ['legbyes', 'None', 'wides', 'byes', 'noballs', 'penalty']

# %%
list=['0','1','2','3','4','5','6']
for i in list:
    imp.append(i)

print(imp)
# Out:
# ['legbyes', 'None', 'wides', 'byes', 'noballs', 'penalty', '0', '1', '2', '3', '4', '5', '6']

# %%
merged_df.head(100)
# Out:
#     match_id  inning           batting_team                 bowling_team  \
# 0     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 5     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 6     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 7     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 8     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 9     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 10    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 11    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...

# %%
list = []

for i in merged_df['match_id'].unique():
    match_data = merged_df[merged_df['match_id'] == i]
    for index, row in match_data.iterrows():
        if row['extras_type'] == 'None' and row['batsman_runs'] == 0:
            list.append('0')
        elif row['extras_type'] != 'None' and row['batsman_runs'] == 0:
            list.append(row['extras_type'])
        elif row['batsman_runs'] == 1:
            list.append('1')
        elif row['batsman_runs'] == 2:
            list.append('2')
        elif row['batsman_runs'] == 3:
            list.append('3')
        elif row['batsman_runs'] == 4:
            list.append('4')
        elif row['batsman_runs'] == 5:
            list.append('5')
        elif row['batsman_runs'] == 6:
            list.append('6')

# %%
len(list)
# Out:
# 260920

# %%
merged_df['target_column']= list

# %%
merged_df.head(30)
# Out:
#     match_id  inning           batting_team                 bowling_team  \
# 0     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 5     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 6     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 7     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 8     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 9     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 10    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 11    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...

# %%
merged_df[['match_id','batsman_runs','extra_runs','total_runs','extras_type','target_column']].head(30)
# Out:
#     match_id  batsman_runs  extra_runs  total_runs extras_type target_column
# 0     335982             0           1           1     legbyes       legbyes
# 1     335982             0           0           0        None             0
# 2     335982             0           1           1       wides         wides
# 3     335982             0           0           0        None             0
# 4     335982             0           0           0        None             0
# 5     335982             0           0           0        None             0
# 6     335982             0           1           1     legbyes       legbyes
# 7     335982             0           0           0        None             0
# 8     335982             4           0           4        None             4
# 9     335982             4           0           4        None             4
# 10    335982             6           0           6        None             6
# ...

# %%
merged_df.to_csv('EDA2_dataset.csv')

# %%
merged_df.shape
# Out:
# (260920, 30)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       260920 non-null  object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  260920 non-null  object
#  15  dismissal_kind    260920 non-null  object
# ...

# %%
sample = merged_df.head(220)

# %%
sample.to_csv('sample_dataset.csv')

# %%
sample.head(100)
# Out:
#     match_id  inning           batting_team                 bowling_team  \
# 0     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 5     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 6     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 7     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 8     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 9     335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 10    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 11    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...

# %%
# merged_df = merged_df.drop(['overall_over'],axis=1)

# %%
merged_df.head(3)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# 0           1     legbyes          0             None        Not-out    None
# 1           0        None          0             None        Not-out    None
# 2           1       wides          0             None        Not-out    None
#
#         city player_of_match                  venue  \
# ...

# %%
merged_df['overall_over']= merged_df['over'] + (merged_df['ball'] / 10)

# %%
merged_df[merged_df['extras_type']=='noballs'].head(10)
# Out:
#       match_id  inning           batting_team           bowling_team  over  \
# 239     335983       1    Chennai Super Kings        Kings XI Punjab     2
# 939     335986       1        Deccan Chargers  Kolkata Knight Riders     0
# 984     335986       1        Deccan Chargers  Kolkata Knight Riders     7
# 1132    335986       2  Kolkata Knight Riders        Deccan Chargers    11
# 1294    335987       1        Kings XI Punjab       Rajasthan Royals    19
# 1301    335987       2       Rajasthan Royals        Kings XI Punjab     0
# 1313    335987       2       Rajasthan Royals        Kings XI Punjab     1
# 1319    335987       2       Rajasthan Royals        Kings XI Punjab     2
# 1391    335987       2       Rajasthan Royals        Kings XI Punjab    13
# 1539    335988       1        Deccan Chargers       Delhi Daredevils    19
#
#       ball           batter           bowler   non_striker  batsman_runs  \
# ...

# %%
merged_df[merged_df['match_id']==335983]
# Out:
#      match_id  inning         batting_team         bowling_team  over  ball  \
# 225    335983       1  Chennai Super Kings      Kings XI Punjab     0     1
# 226    335983       1  Chennai Super Kings      Kings XI Punjab     0     2
# 227    335983       1  Chennai Super Kings      Kings XI Punjab     0     3
# 228    335983       1  Chennai Super Kings      Kings XI Punjab     0     4
# 229    335983       1  Chennai Super Kings      Kings XI Punjab     0     5
# 230    335983       1  Chennai Super Kings      Kings XI Punjab     0     6
# 231    335983       1  Chennai Super Kings      Kings XI Punjab     1     1
# 232    335983       1  Chennai Super Kings      Kings XI Punjab     1     2
# 233    335983       1  Chennai Super Kings      Kings XI Punjab     1     3
# 234    335983       1  Chennai Super Kings      Kings XI Punjab     1     4
# 235    335983       1  Chennai Super Kings      Kings XI Punjab     1     5
# ...

# %%
sample = merged_df[merged_df['match_id']==335983]

# %%
sample = merged_df[merged_df['match_id']==335983]

# %%
merged_df.head(3)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# 0           1     legbyes          0             None        Not-out    None
# 1           0        None          0             None        Not-out    None
# 2           1       wides          0             None        Not-out    None
#
#         city player_of_match                  venue  \
# ...

# %%
batsman_strike_rates = merged_df.groupby('batter')['batsman_runs'].sum().reset_index()

# %%
batsman_strike_rates.rename(columns={'Runs': 'Total_Runs'}, inplace=True)

# %%
batsman_strike_rates
# Out:
#                       batter  batsman_runs
# 0             A Ashish Reddy           280
# 1                   A Badoni           634
# 2                 A Chandila             4
# 3                   A Chopra            53
# 4                A Choudhary            25
# 5                A Dananjaya             4
# 6                 A Flintoff            62
# 7                   A Kamboj             2
# 8                   A Kumble            35
# 9                  A Manohar           231
# 10                  A Mishra           381
# 11                  A Mithun            34
# 12                  A Mukund            19
# 13                   A Nehra            41
# 14                  A Nortje            49
# 15             A Raghuvanshi           163
# 16                   A Singh             2
# 17                 A Symonds           974
# 18                   A Tomar             4
# 19                  A Uniyal             4
# 20                   A Zampa            15
# ...

# %%
merged_df[merged_df['batter']=='A Dananjaya']
# Out:
#         match_id  inning    batting_team      bowling_team  over  ball  \
# 152403   1136569       1  Mumbai Indians  Delhi Daredevils    18     4
# 152404   1136569       1  Mumbai Indians  Delhi Daredevils    18     5
# 152405   1136569       1  Mumbai Indians  Delhi Daredevils    18     6
# 152407   1136569       1  Mumbai Indians  Delhi Daredevils    19     2
# 152410   1136569       1  Mumbai Indians  Delhi Daredevils    19     5
#
#              batter          bowler non_striker  batsman_runs  extra_runs  \
# 152403  A Dananjaya  Mohammed Shami   HH Pandya             0           0
# 152404  A Dananjaya  Mohammed Shami   HH Pandya             2           0
# 152405  A Dananjaya  Mohammed Shami   HH Pandya             0           0
# 152407  A Dananjaya        TA Boult  M Markande             1           0
# 152410  A Dananjaya        TA Boult  M Markande             1           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# ...

# %%
batsman_balls_played = merged_df.groupby('batter')['ball'].count().reset_index()

# %%
batsman_balls_played
# Out:
#                       batter  ball
# 0             A Ashish Reddy   196
# 1                   A Badoni   505
# 2                 A Chandila     7
# 3                   A Chopra    75
# 4                A Choudhary    20
# 5                A Dananjaya     5
# 6                 A Flintoff    57
# 7                   A Kamboj     2
# 8                   A Kumble    49
# 9                  A Manohar   181
# 10                  A Mishra   440
# 11                  A Mithun    26
# 12                  A Mukund    23
# 13                   A Nehra    63
# 14                  A Nortje    51
# 15             A Raghuvanshi   109
# 16                   A Singh    10
# 17                 A Symonds   781
# 18                   A Tomar     8
# 19                  A Uniyal     7
# 20                   A Zampa    25
# 21               AA Bilakhia    88
# 22                 AA Chavan    11
# 23           AA Jhunjhunwala   218
# 24               AA Kulkarni     8
# 25                 AA Noffke    12
# ...

# %%
merged_df[merged_df['batter']=='A Kamboj']
# Out:
#         match_id  inning    batting_team           bowling_team  over  ball  \
# 258298   1426298       2  Mumbai Indians  Kolkata Knight Riders    15     2
# 258302   1426298       2  Mumbai Indians  Kolkata Knight Riders    15     6
#
#           batter        bowler  non_striker  batsman_runs  extra_runs  \
# 258298  A Kamboj  Harshit Rana  Tilak Varma             1           0
# 258302  A Kamboj  Harshit Rana    PP Chawla             1           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 258298           1        None          0             None        Not-out
# 258302           1        None          0             None        Not-out
#
#        fielder     city player_of_match                  venue  \
# 258298    None  Kolkata        CV Varun  Eden Gardens, Kolkata
# 258302    None  Kolkata        CV Varun  Eden Gardens, Kolkata
#
#            toss_winner toss_decision                 winner result  \
# ...

# %%
merged_df['is_wicket'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
merged_Batsman = pd.merge(batsman_strike_rates, batsman_balls_played, on='batter')

# %%
merged_Batsman.head()
# Out:
#            batter  batsman_runs  ball
# 0  A Ashish Reddy           280   196
# 1        A Badoni           634   505
# 2      A Chandila             4     7
# 3        A Chopra            53    75
# 4     A Choudhary            25    20

# %%
merged_Batsman['batsman_Strike_Rate'] = (merged_Batsman['batsman_runs'] / merged_Batsman['ball']) * 100
merged_Batsman['batsman_Strike_Rate'] = merged_Batsman['batsman_Strike_Rate'].round(2)

# %%
merged_Batsman.head()
# Out:
#            batter  batsman_runs  ball  batsman_Strike_Rate
# 0  A Ashish Reddy           280   196               142.86
# 1        A Badoni           634   505               125.54
# 2      A Chandila             4     7                57.14
# 3        A Chopra            53    75                70.67
# 4     A Choudhary            25    20               125.00

# %%
df2 =merged_df.groupby('batter')['match_id'].nunique().reset_index()

# %%
merged_Batsman = pd.merge(merged_Batsman, df2, on='batter')

# %%
merged_Batsman.head()
# Out:
#            batter  batsman_runs  ball  batsman_Strike_Rate  match_id
# 0  A Ashish Reddy           280   196               142.86        23
# 1        A Badoni           634   505               125.54        35
# 2      A Chandila             4     7                57.14         2
# 3        A Chopra            53    75                70.67         6
# 4     A Choudhary            25    20               125.00         3

# %%
# merged_Batsman=merged_Batsman.drop('match_id_x',axis=1)

# %%
merged_Batsman.head()
# Out:
#            batter  batsman_runs  ball  batsman_Strike_Rate  match_id
# 0  A Ashish Reddy           280   196               142.86        23
# 1        A Badoni           634   505               125.54        35
# 2      A Chandila             4     7                57.14         2
# 3        A Chopra            53    75                70.67         6
# 4     A Choudhary            25    20               125.00         3

# %%
merged_Batsman['matches_played']=merged_Batsman['match_id']

# %%
merged_Batsman.head()
# Out:
#            batter  batsman_runs  ball  batsman_Strike_Rate  match_id  \
# 0  A Ashish Reddy           280   196               142.86        23
# 1        A Badoni           634   505               125.54        35
# 2      A Chandila             4     7                57.14         2
# 3        A Chopra            53    75                70.67         6
# 4     A Choudhary            25    20               125.00         3
#
#    matches_played
# 0              23
# 1              35
# 2               2
# 3               6
# 4               3

# %%
# merged_Batsman=merged_Batsman.drop('match_id_y',axis=1)

# %%
merged_Batsman.head()
# Out:
#            batter  batsman_runs  ball  batsman_Strike_Rate  match_id  \
# 0  A Ashish Reddy           280   196               142.86        23
# 1        A Badoni           634   505               125.54        35
# 2      A Chandila             4     7                57.14         2
# 3        A Chopra            53    75                70.67         6
# 4     A Choudhary            25    20               125.00         3
#
#    matches_played
# 0              23
# 1              35
# 2               2
# 3               6
# 4               3

# %%
df3 =merged_df[['batter','is_wicket','match_id']]

# %%
merged_df.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# ...

# %%
df3 = df3.iloc[np.where(df3['is_wicket']==0)]

# %%
df3.head()
# Out:
#         batter  is_wicket  match_id
# 0   SC Ganguly          0    335982
# 1  BB McCullum          0    335982
# 2  BB McCullum          0    335982
# 3  BB McCullum          0    335982
# 4  BB McCullum          0    335982

# %%
df3=df3.groupby('batter')['match_id'].nunique().reset_index()

# %%
df3.head()
# Out:
#            batter  match_id
# 0  A Ashish Reddy        23
# 1        A Badoni        34
# 2      A Chandila         1
# 3        A Chopra         6
# 4     A Choudhary         3

# %%
merged_Batsman['matches_not_out']=df3['match_id']

# %%
merged_Batsman.head()
# Out:
#            batter  batsman_runs  ball  batsman_Strike_Rate  match_id  \
# 0  A Ashish Reddy           280   196               142.86        23
# 1        A Badoni           634   505               125.54        35
# 2      A Chandila             4     7                57.14         2
# 3        A Chopra            53    75                70.67         6
# 4     A Choudhary            25    20               125.00         3
#
#    matches_played  matches_not_out
# 0              23             23.0
# 1              35             34.0
# 2               2              1.0
# 3               6              6.0
# 4               3              3.0

# %%
(len(merged_df['match_id'].unique())-merged_Batsman['matches_played'])
# Out:
# 1095

# %%
merged_Batsman['batsman_avg_runs']=(merged_Batsman['batsman_runs']/((1095-merged_Batsman['matches_played'])-merged_Batsman['matches_not_out']))*100
merged_Batsman['batsman_avg_runs']=merged_Batsman['batsman_avg_runs'].round(2)
merged_Batsman.head()
# Out:
#            batter  batsman_runs  ball  batsman_Strike_Rate  match_id  \
# 0  A Ashish Reddy           280   196               142.86        23
# 1        A Badoni           634   505               125.54        35
# 2      A Chandila             4     7                57.14         2
# 3        A Chopra            53    75                70.67         6
# 4     A Choudhary            25    20               125.00         3
#
#    matches_played  matches_not_out  batsman_avg_runs
# 0              23             23.0             26.69
# 1              35             34.0             61.79
# 2               2              1.0              0.37
# 3               6              6.0              4.89
# 4               3              3.0              2.30

# %%
merged_df.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# ...

# %%
merged_df = merged_df.rename(columns={'bowler':'baller'})

# %%
baller_data = merged_df[['baller','match_id','inning','over','ball','batsman_runs']]

# %%
baller_data.head()
# Out:
#     baller  match_id  inning  over  ball  batsman_runs
# 0  P Kumar    335982       1     0     1             0
# 1  P Kumar    335982       1     0     2             0
# 2  P Kumar    335982       1     0     3             0
# 3  P Kumar    335982       1     0     4             0
# 4  P Kumar    335982       1     0     5             0

# %%
new_df = baller_data.groupby('baller')['batsman_runs'].sum().reset_index()
new_df.head(40)
# Out:
#              baller  batsman_runs
# 0    A Ashish Reddy           386
# 1          A Badoni            36
# 2        A Chandila           242
# 3       A Choudhary           137
# 4       A Dananjaya            46
# 5        A Flintoff           105
# 6          A Kamboj           106
# 7          A Kumble          1027
# 8          A Mishra          4065
# 9          A Mithun           448
# 10          A Nehra          2422
# 11            A Nel            31
# 12         A Nortje          1523
# 13          A Singh           603
# 14        A Symonds           656
# 15         A Uniyal            64
# 16          A Zampa           547
# 17        AA Chavan           318
# 18  AA Jhunjhunwala           126
# 19          AA Kazi            20
# 20        AA Noffke            35
# 21       AB Agarkar          1112
# 22         AB Dinda          1987
# 23      AB McDonald           259
# 24     AC Gilchrist             0
# 25        AC Thomas           394
# ...

# %%
new_df=new_df.rename(columns={'batsman_runs':'conceded_runs'})
new_df.head()
# Out:
#            baller  conceded_runs
# 0  A Ashish Reddy            386
# 1        A Badoni             36
# 2      A Chandila            242
# 3     A Choudhary            137
# 4     A Dananjaya             46

# %%
baller_data[baller_data['baller']=='AM Rahane']
# Out:
#           baller  match_id  inning  over  ball  batsman_runs
# 22785  AM Rahane    392222       1    14     1             2
# 22786  AM Rahane    392222       1    14     2             0
# 22787  AM Rahane    392222       1    14     3             0
# 22788  AM Rahane    392222       1    14     4             1
# 22789  AM Rahane    392222       1    14     5             1
# 22790  AM Rahane    392222       1    14     6             1

# %%
baller_data.head()
# Out:
#     baller  match_id  inning  over  ball  batsman_runs
# 0  P Kumar    335982       1     0     1             0
# 1  P Kumar    335982       1     0     2             0
# 2  P Kumar    335982       1     0     3             0
# 3  P Kumar    335982       1     0     4             0
# 4  P Kumar    335982       1     0     5             0

# %%
x=baller_data.groupby('baller')['ball'].count().reset_index()
x
# Out:
#                       baller  ball
# 0             A Ashish Reddy   270
# 1                   A Badoni    25
# 2                 A Chandila   234
# 3                A Choudhary   108
# 4                A Dananjaya    25
# 5                 A Flintoff    66
# 6                   A Kamboj    68
# 7                   A Kumble   983
# 8                   A Mishra  3444
# 9                   A Mithun   312
# 10                   A Nehra  1974
# 11                     A Nel    18
# 12                  A Nortje  1097
# 13                   A Singh   486
# 14                 A Symonds   540
# 15                  A Uniyal    38
# 16                   A Zampa   425
# 17                 AA Chavan   255
# 18           AA Jhunjhunwala    88
# 19                   AA Kazi    13
# 20                 AA Noffke    25
# 21                AB Agarkar   820
# 22                  AB Dinda  1589
# 23               AB McDonald   188
# 24              AC Gilchrist     1
# 25                 AC Thomas   327
# ...

# %%
x['overall_overs']=(x['ball']/6)
x['overall_overs']=x['overall_overs'].round(1)
x.head(50)
# Out:
#              baller  ball  overall_overs
# 0    A Ashish Reddy   270           45.0
# 1          A Badoni    25            4.2
# 2        A Chandila   234           39.0
# 3       A Choudhary   108           18.0
# 4       A Dananjaya    25            4.2
# 5        A Flintoff    66           11.0
# 6          A Kamboj    68           11.3
# 7          A Kumble   983          163.8
# 8          A Mishra  3444          574.0
# 9          A Mithun   312           52.0
# 10          A Nehra  1974          329.0
# 11            A Nel    18            3.0
# 12         A Nortje  1097          182.8
# 13          A Singh   486           81.0
# 14        A Symonds   540           90.0
# 15         A Uniyal    38            6.3
# 16          A Zampa   425           70.8
# 17        AA Chavan   255           42.5
# 18  AA Jhunjhunwala    88           14.7
# 19          AA Kazi    13            2.2
# 20        AA Noffke    25            4.2
# 21       AB Agarkar   820          136.7
# ...

# %%
new_df.head(2)
# Out:
#            baller  conceded_runs
# 0  A Ashish Reddy            386
# 1        A Badoni             36

# %%
x.head(2)
# Out:
#            baller  ball  overall_overs
# 0  A Ashish Reddy   270           45.0
# 1        A Badoni    25            4.2

# %%
x=x.drop('ball',axis=1)

# %%
baller_merged=pd.merge(new_df,x,on='baller')

# %%
baller_merged.head()
# Out:
#            baller  conceded_runs  overall_overs
# 0  A Ashish Reddy            386           45.0
# 1        A Badoni             36            4.2
# 2      A Chandila            242           39.0
# 3     A Choudhary            137           18.0
# 4     A Dananjaya             46            4.2

# %%
baller_merged['baller_economy']=(baller_merged['conceded_runs']/baller_merged['overall_overs'])

# %%
baller_merged['baller_economy']=baller_merged['baller_economy'].round(1)
baller_merged.head()
# Out:
#            baller  conceded_runs  overall_overs  baller_economy
# 0  A Ashish Reddy            386           45.0             8.6
# 1        A Badoni             36            4.2             8.6
# 2      A Chandila            242           39.0             6.2
# 3     A Choudhary            137           18.0             7.6
# 4     A Dananjaya             46            4.2            11.0

# %%
baller_merged=baller_merged.drop(['conceded_runs','overall_overs'],axis=1)

# %%
baller_merged.head()
# Out:
#            baller  baller_economy
# 0  A Ashish Reddy             8.6
# 1        A Badoni             8.6
# 2      A Chandila             6.2
# 3     A Choudhary             7.6
# 4     A Dananjaya            11.0

# %%
merged_Batsman.head()
# Out:
#            batter  batsman_runs  ball  batsman_Strike_Rate  match_id  \
# 0  A Ashish Reddy           280   196               142.86        23
# 1        A Badoni           634   505               125.54        35
# 2      A Chandila             4     7                57.14         2
# 3        A Chopra            53    75                70.67         6
# 4     A Choudhary            25    20               125.00         3
#
#    matches_played  matches_not_out  batsman_avg_runs
# 0              23             23.0             26.69
# 1              35             34.0             61.79
# 2               2              1.0              0.37
# 3               6              6.0              4.89
# 4               3              3.0              2.30

# %%
merged_Batsman=merged_Batsman.drop(['batsman_runs','ball','match_id','matches_played'],axis=1)

# %%
merged_Batsman.head()
# Out:
#            batter  batsman_Strike_Rate  matches_not_out  batsman_avg_runs
# 0  A Ashish Reddy               142.86             23.0             26.69
# 1        A Badoni               125.54             34.0             61.79
# 2      A Chandila                57.14              1.0              0.37
# 3        A Chopra                70.67              6.0              4.89
# 4     A Choudhary               125.00              3.0              2.30

# %%
merged_df= pd.merge(merged_df,baller_merged,on='baller')

# %%
merged_df.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   baller  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# ...

# %%
merged_df=pd.merge(merged_df,merged_Batsman,on='batter')
merged_df.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   baller  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder  \
# ...

# %%
merged_df.shape
# Out:
# (260920, 35)
